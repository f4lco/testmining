# %%
from util import setup_notebook
setup_notebook()
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd

# %%
with pd.HDFStore('../output/builds.hd5') as store:
    builds = store['builds']
builds.head()
# Out:
#                gh_project_name gh_lang  gh_pull_req_num  gh_is_pr  git_branch  \
# tr_build_id
# 106060             rails/rails    ruby              NaN     False  3-1-stable
# 106176             rails/rails    ruby              NaN     False      master
# 106236       intridea/omniauth    ruby              NaN     False      master
# 106306        myronmarston/vcr    ruby              NaN     False      master
# 106359       intridea/omniauth    ruby              NaN     False      master
#
#                                          git_all_built_commits  test_failures  \
# tr_build_id
# 106060       [ca26feb54aa7d994831fc33e23fd46adda73358c, 97e...          False
# 106176       [cfe7548aef1b005e49eacd8b0177764e77643ccf, cfe...          False
# 106236       [b8041a817ab028ec73305c4cc2202882203562c4, b80...          False
# 106306       [1a5a77084a79a1ca5d94a72bef307c2ae3ed47c5, 1a5...          False
# 106359       [abe1d1c9aa912c315904023ee6938191befbfb3b, abe...          False
#
#              tr_duration  tr_log_testduration  tr_log_buildduration
# tr_build_id
# 106060          156165.0                 0.00                   0.0
# 106176          185910.0                 0.00                   0.0
# 106236            6210.0                 8.24                   0.0
# 106306            5952.0               283.81                   0.0
# 106359            5418.0                 7.59                   0.0

# %% [markdown]
# # Ruby
#
# Generally hard to parse build logs, it just possible to infer how many tests passed or failed. At most '.' is printed for executed test cases, no names, no nothing.
#
# Example parser: https://github.com/TestRoots/travistorrent-tools/blob/master/lib/languages/ruby_log_file_analyzer.rb

# %% [markdown]
# ## Rails
#
# Looks promising, total outlier w.r.t. to test count and test failures, however: the usual Ruby caveats apply. Infering untreated test order is hard.

# %% [markdown]
# # Java
#
# This is possibly restricted to Maven projects. At least the test class names are printed out.
#
# Example parser: https://github.com/TestRoots/travistorrent-tools/blob/master/lib/languages/java_maven_log_file_analyzer.rb

# %% [markdown]
# ## Projects from 'Practical Regression Test Selection with Dynamic File Dependencies'

# %%
pn = list(builds['gh_project_name'].unique())
l = [
    'cucumber',
    'joda',
    'retrofit',
    'validator',
    'bval',
    'jxpath',
    'hopper',
    'river',
    'functor',
    'empire',
    'jfreechart',
    'commons',
    'apache',
    'pdfbox',
    'gscollections',
    'closure',
    'log4j',
    'jgit',
    'ivy',
    'jenkins',
    'ant',
    'continuum',
    'guava',
    'camel',
    'jetty',
    'hadoop',
    'zookeeper',
]

matches = []
for candidate in l:
    matches.append((candidate, [x for x in pn if candidate in x]))
matches
# Out:
# [('cucumber', []),
#  ('joda', ['JodaOrg/joda-time']),
#  ('retrofit', ['square/retrofit']),
#  ('validator', ['franckverrot/activevalidators', 'validator/validator']),
#  ('bval', []),
#  ('jxpath', []),
#  ('hopper', ['graphhopper/graphhopper', 'twitter/cloudhopper-smpp']),
#  ('river',
#   ['rest-driver/rest-driver', 'datastax/ruby-driver', 'datastax/java-driver']),
#  ('functor', []),
#  ('empire', []),
#  ('jfreechart', []),
#  ('commons',
#   ['Casecommons/pg_search',
#    'twitter/commons',
#    'futuresimple/android-db-commons']),
#  ('apache',
#   ['apache/jackrabbit-oak',
#    'eapache/starscope',
#    'apache/drill',
#    'apache/tajo',
#    'apache/sling',
#    'apache/storm',
#    'apache/flink']),
#  ('pdfbox', []),
#  ('gscollections', []),
#  ('closure', ['mceachen/closure_tree', 'google/closure-compiler']),
#  ('log4j', []),
#  ('jgit', []),
#  ('ivy', []),
#  ('jenkins', ['jenkinsci/jenkins.rb', 'arangamani/jenkins_api_client']),
#  ('ant',
#   ['codeforamerica/adopt-a-hydrant',
#    'radiant/radiant',
#    'colinsurprenant/redstorm',
#    'mitchellh/vagrant',
#    'Sutto/rocket_pants',
#    'ananthakumaran/fake_dynamo',
#    'kostyantyn/hydra_attribute',
#    'mbj/mutant',
#    'ryantenney/metrics-spring',
#    'dkubb/adamantium',
#    'twitter/elephant-bird',
#    'antirez/redis-doc',
#    'maoueh/nugrant',
#    'fgrehm/vagrant-lxc',
#    'cantino/huginn',
#    'cassianoleal/vagrant-butcher',
#    'berkshelf/vagrant-berkshelf',
#    'jdantonio/functional-ruby',
#    'WinRb/vagrant-windows',
#    'jprante/elasticsearch-jdbc',
#    'test-kitchen/kitchen-vagrant',
#    'Parallels/vagrant-parallels',
#    'anthonycr/Lightning-Browser',
#    'palantir/eclipse-typescript',
#    'cantino/reckon']),
#  ('continuum', []),
#  ('guava', ['google/guava']),
#  ('camel', []),
#  ('jetty', ['eclipse/jetty.project']),
#  ('hadoop', []),
#  ('zookeeper', [])]

# %% [markdown]
# ## Guava

# %%
# Guava
guava = builds[builds['gh_project_name'] == 'google/guava']

# only master builds
guava['git_branch'].unique()
# Out:
# array(['master'], dtype=object)

# %%
# Test failures?
guava[guava['test_failures']]
# Out:
#             gh_project_name gh_lang  gh_pull_req_num  gh_is_pr git_branch  \
# tr_build_id
# 144632195      google/guava    java              NaN     False     master
# 148395413      google/guava    java              NaN     False     master
# 154544197      google/guava    java              NaN     False     master
#
#                                          git_all_built_commits  test_failures  \
# tr_build_id
# 144632195    [522debc80a9d3df903a018ea54f8aa419e82c44e, 522...           True
# 148395413    [4bfb25c13ad69f837c5171172517b9b109d6d5f6, b63...           True
# 154544197    [16d03d56aa85457a91b48f5b05dbf1701b2e880d, af1...           True
#
#              tr_duration  tr_log_testduration  tr_log_buildduration
# tr_build_id
# 144632195        13050.0              2296.68                3644.0
# 148395413        12498.0              2081.73                3400.0
# 154544197        14613.0              2337.56                3664.0

# %% [markdown]
# ## Retrofit

# %%
retrofit = builds[builds['gh_project_name'] == 'square/retrofit']
retrofit['git_branch'].unique()
# Out:
# array(['master', 'jw/callback-api-stuff', 'jw/javadoc-tweak',
#        'jw/converter', 'jw/floater', 'jw/hide-and-seek', 'jw/inject',
#        'jw/builder', 'jw/examples', 'jw/unused', 'jw/doin-thangs',
#        'jw/byte-me', 'jw/copy-tweak', 'jw/objects', 'jw/synchronous',
#        'jw/kill-jarjar-binks', 'jw/cleanup-some-things',
#        'jw/twitter-example', 'jw/constant', 'jw/files-flies',
#        'jw/flip-the-world', 'jw/executors', 'jw/impl-hiding',
#        'jw/synchronous-post', 'jw/log-things', 'jw/things', 'jw/redund',
#        'jw/optional-callback-executor', 'jw/executors-exceptions',
#        'jw/defaults', 'jw/nomenclature',
#        'pforhan/dont-load-platform-unless-needed', 'jw/singleton',
#        'edenman/fix-multibyte-length', 'jw/throwin-hundreds', 'jw/files',
#        'jw/generalize', 'jw/docs', 'jw/utf8-or-gtfo', 'jw/cache',
#        'jw/defer', 'jw/interfaces-only-bro', 'jw/abstract-http-client',
#        'jw/response-object', 'jw/kill-all-mimes', 'jw/small',
#        'jw/footers', 'jw/typed-things', 'jw/package-move',
#        'jw/drop-jsr-330', 'jw/request-typed', 'jw/weary-query',
#        'jw/point-to-things', 'jw/log-request-more-like-yeah',
#        'jw/dont-call-it-earl', 'jw/charset', 'jwilson/types',
#        'jw/fix-sample', 'jw/apache-tweaks', 'jw/lumber-jack',
#        'jw/multiparty', 'jw/eager-stream-read', 'jw/thread-name-reset',
#        'jw/gee-son', 'jw/rewrite-all-the-things', 'jw/normalize',
#        'jwilson/doc_nitpicks', 'jw/bad-bad-intellij', 'jw/static-query',
#        'jw/gson-update', 'jw/nulls', 'jw/earl', 'jw/interceptor',
#        'jw/timeouts', 'jw/static-headers', 'jw/optional-part',
#        'jw/strings', 'jw/doc-tweak', 'jw/plank', 'jw/docs-docs-docs',
#        'jw/platform-detection', 'jw/headers', 'jw/protos',
#        'jw/log-exceptions', 'jw/documented', 'jw/no-extends',
#        'jw/propagate-network-exceptions', 'jw/fix-encoded-path-cast',
#        'jw/omar-comin-yo', 'jw/sheeeeeeeeeeeit', 'rice/wire_input_stream',
#        'jw/ok-defaults', 'jw/dont-mock-me', 'jw/mock-adapter',
#        'jw/doc-log-level', 'jw/bump-things', 'jw/helpers',
#        'loganj/last_arg_test', 'jw/fix-broken-mock', 'parent-1.3.0',
#        'loganj/more_indirection', 'jw/naming', 'jw/iterable',
#        'jw/query-map', 'jw/field-map', 'jw/primitive-array-iteration',
#        'parent-1.4.0', 'parent-1.4.1', 'jw/exception-overhaul',
#        'jw/rx-twewaks', 'jw/useless-method', 'jw/emmmmmmmmmmmma',
#        'jw/appengine', 'jw/patch-up-patch',
#        'jw/what-were-you-thinking-george-lucas', 'parent-1.5.0',
#        'jw/mock-error-handler', 'edenman/lazy-build-rx-support',
#        'parent-1.5.1', 'jw/deprecated', 'jw/init-in-try-catch',
#        'jw/document-field', 'jw/exception-messages',
#        'jw/mock-async-sleep-before-callback', 'jwilson_0527_okhttp_16',
#        'jw/converter-docs', 'jw/apply-interceptor-tape-on-subscribe',
#        'jw/no-body', 'jw/fix-content-type-mess', 'jw/test',
#        'jw/update-rx', 'jw/remove-catch', 'jw/endpoints-test',
#        'jw/expose-success-type', 'parent-1.6.0', 'version-one',
#        'edenman/dont-blow-up-on-null-bodies', 'jw/wtf-dot-net',
#        'jw/content-type-header-no-body', 'parent-1.6.1',
#        'jw/only-content-type-header', 'rice/log_headers_and_args',
#        'ray/wire-conv', 'jw/gson-charset', 'jw/fetch-client-content-type',
#        'jw/fetch-client-null-url', 'jw/content-transfer-encoding',
#        'jw/whiteboxish', 'jw/document-exception-behavior',
#        'jw/annotations', 'jw/error-kind', 'jw/mock-scheduling',
#        'parent-1.7.0', 'jw/remove-deprecated-methods',
#        'jw/kill-endpoint-naes', 'jw/kill-response-callback',
#        'jw/client-provider-death', 'jw/remove-profiler',
#        'jw/break-app-engine-out', 'edenman/update-rxjava',
#        'rice/fix_log_npe', 'parent-1.7.1', 'parent-1.8.0',
#        'jw/new-redirect-link', 'jw/iterable-headers', 'jw/auto-deploy',
#        'jw/okhttp-two', 'jw/null-header-values', 'parent-1.9.0',
#        'jw/async-client', 'jw/endpoint', 'jw/loggy', 'jw/no-more-tape',
#        'jw/pass-type-to-serializer', 'jw/okhttp-is-the-client',
#        'jw/exceptions', 'jw/simplify-http-annotations',
#        'jw/destroy-client', 'jw/form-encoding', 'jw/two-oh-four-and-five',
#        'jw/builder-updates', 'jw/remove-interceptor',
#        'jw/built-in-form-builder', 'jw/encoded', 'jw/samples',
#        'jw/this-changes-everything', 'jw/do-not-bring-a-converter-along',
#        'jw/value-change-listener', 'jw/casing', 'jw/sane-tests',
#        'jw/converters', 'jw/only-one-call-adapter-factory', 'jw/bounds',
#        'jw/restore', 'jw/unused-path-param', 'jw/http-url', 'jw/branding',
#        'jw/logic', 'jw/include-request-body', 'jw/moshi',
#        'jw/converter-integration-tests', 'jw/converter-factory',
#        'jw/parameter-actions', 'jw/rearchitect-parsing',
#        'jw/test-coverage', 'jw/expose-executor-call-adapter-factory',
#        'jw/base-url', 'jw/url', 'jwilson_0629_latest_version',
#        'jw/websocket', 'jw/non-timing-based-buffer-and-stream',
#        'jw/mws-http-url', 'jwilson_0708_cancel', 'jwilson_0708_onSuccess',
#        'jw/the-mock-night-rises', 'jw/restore-mock-sample',
#        'jw/allow-non-retrofit-annotations', 'jw/mws', 'jw/mock',
#        'jw/result-helpers-public', 'jw/http-exception',
#        'jw/http-is-not-io', 'jw/multiple-converters-and-call-adapters',
#        'jwilson_0822_converter', 'jwilson_0822_contenttype',
#        'jw/rxjava-single', 'jw/network-behavior', 'jw/java-eight',
#        'jw/rxjava-latest', 'jw/okhttp-two-five-final',
#        'parent-2.0.0-beta1', 'jw/call-adapter-generics', 'jw/website',
#        'jw/fixurup', 'jw/void-converter', 'jw/new-converter-api',
#        'jw/eager', 'jw/call-adapter-delegation', 'jw/converter-methods',
#        'jw/provide-retrofit', 'jw/shutdown', 'jw/path-encoding',
#        'jw/head-must-be-void', 'jw/consolidate-response-bodies',
#        'jw/consolidate-converters', 'jw/moshi-one',
#        'jw/temporary-gson-workaround', 'parent-2.0.0-beta2', 'jw/remove',
#        'jw/simple-examples', 'jw/gson-two-four', 'jw/wire-2',
#        'jwilson_1026_update_javadoc_links', 'jw/revert-callback-retrofit',
#        'jw/all-custom-call-adapter', 'jw/response', 'jw/url-docs',
#        'jw/request-action', 'jw/caching-build-in-converters',
#        'jw/abstract-iterable-and-array-param-actions',
#        'jw/string-converter', '1zaman-delivery-cancellation',
#        'jw/call-is-executed', 'jw/scalars',
#        'jw/delegating-converters-with-chunking-sample', 'jw/move',
#        'jw/iterable-array-part', 'jw/two', 'jw/new-mock', 'jw/javadoc',
#        'jw/path', 'jw/wrong-generic', 'jw/canceled-io-throw',
#        'jw/mock-builder', 'jw/call-factory', 'jw/needless',
#        'jw/double-cause', 'jw/nuke-synthetics',
#        'jw/visiblity-housekeeping', 'jw/some-docs', 'jw/okhttp-three',
#        'jw/forbid-response-response-types', 'jwilson_0101_callfactory',
#        'jw/fix-tests', 'jw/new-okhttp-apis', 'jw/import',
#        'jw/resolve-to-builder', 'jw/stable-okhttp', 'jw/url-uris',
#        'parent-2.0.0-beta3', 'jw/call-argument', 'jw/call-get-request',
#        'jw/simplify-close', 'jw/do-not-trap-io',
#        'setheclark-exception_msg_correction', 'jw/rx-tests',
#        'jw/guava-adapter', 'jw/default-methods', 'jw/generic',
#        'jw/converter-packages', 'jw/adapter-util-methods',
#        'jw/json-as-string-converter', 'jw/annotation-delegation',
#        'jw/resolve-generic-types', 'f2prateek-method-annotations-2',
#        'parent-2.0.0-beta4', 'jw/okhttp-three-one', 'jw/okhttp',
#        'jw/malformed-resolve', 'jw/gson-lenient-reading', 'jw/schedulers',
#        'jwilson_0221_issue_template', 'jw/propagate-executor',
#        'jw/callback-executor-in-sample', 'jw/forbid-null-in-maps',
#        'jwilson_0305_requestfactorybiulder', 'jwilson_0306_servicemethod',
#        'jwilson_0306_no_mutable_base_url',
#        'jwilson_0306_dynamic_base_example', 'jw/nully',
#        'jw/death-to-accessor-methods', 'jw/multipart-part-parts',
#        'parent-2.0.0', 'jwilson_0313_sigh_async', 'jwilson_0314_httpurl',
#        'jwilson_0314_crawler_example', 'jw/no-nulls', 'jw/under-pressure',
#        'jw/iterable-and-array-part', 'parent-2.0.1', 'jw/proto-registry',
#        'jw/skim', 'jw/adapter-docs', 'jw/correct-call', 'jw/crappydoc',
#        'jw/test-exposed-util-behavior', 'parent-2.0.2', 'jw/sanity',
#        'jw/xml-char-stream', 'jw/nuke-stack', 'jw/malformed-content-type',
#        'jw/moshi-qualifiers', 'parent-2.1.0',
#        'jw/string-converter-for-string', 'jw/drop-the-bom', 'jw/proto3',
#        'jw/remove-duplicate-test', 'jw/rex', 'jw/to-string',
#        'jw/throw-fatal'], dtype=object)

# %%
retrofit[retrofit[]]
# Out:
#   File "<ipython-input-22-1404e5bcc6ac>", line 1
#     retrofit[retrofit[]]
#                       ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## JRuby
