# %%
from util import setup_notebook
setup_notebook()
# %load_ext autoreload
# %autoreload 2

# %%
import re
import altair as alt
import pandas as pd
from testmining import apfd
from testmining.util import find_files

# %%
base_dir = '../output/okhttp/matrix-window-size'
file_regex = re.compile('square-okhttp-matrix-(\d+).csv')
files = find_files(base_dir, file_regex, converter=int)

            
df = pd.DataFrame(files, columns=['windowSize', 'filename']).sort_values(by='windowSize').reset_index(drop=True)
df['apfd'] = df['filename'].apply(apfd.file_apfd)
df
# Out:
#     windowSize                                           filename      apfd
# 0            0  ../output/okhttp/matrix-window-size/square-okh...  0.467872
# 1           20  ../output/okhttp/matrix-window-size/square-okh...  0.675352
# 2           40  ../output/okhttp/matrix-window-size/square-okh...  0.679292
# 3           60  ../output/okhttp/matrix-window-size/square-okh...  0.678768
# 4           80  ../output/okhttp/matrix-window-size/square-okh...  0.675458
# 5          100  ../output/okhttp/matrix-window-size/square-okh...  0.670583
# 6          120  ../output/okhttp/matrix-window-size/square-okh...  0.667151
# 7          140  ../output/okhttp/matrix-window-size/square-okh...  0.665804
# 8          160  ../output/okhttp/matrix-window-size/square-okh...  0.667227
# 9          180  ../output/okhttp/matrix-window-size/square-okh...  0.668197
# 10         200  ../output/okhttp/matrix-window-size/square-okh...  0.670878
# 11         220  ../output/okhttp/matrix-window-size/square-okh...  0.670151
# 12         240  ../output/okhttp/matrix-window-size/square-okh...  0.670680
# 13         260  ../output/okhttp/matrix-window-size/square-okh...  0.670218
# 14         280  ../output/okhttp/matrix-window-size/square-okh...  0.670080
# 15         300  ../output/okhttp/matrix-window-size/square-okh...  0.669752
# 16         320  ../output/okhttp/matrix-window-size/square-okh...  0.669610
# 17         340  ../output/okhttp/matrix-window-size/square-okh...  0.669486
# 18         360  ../output/okhttp/matrix-window-size/square-okh...  0.669610
# 19         380  ../output/okhttp/matrix-window-size/square-okh...  0.669731
# 20         400  ../output/okhttp/matrix-window-size/square-okh...  0.670112
# 21         420  ../output/okhttp/matrix-window-size/square-okh...  0.670112
# 22         440  ../output/okhttp/matrix-window-size/square-okh...  0.670101
# 23         460  ../output/okhttp/matrix-window-size/square-okh...  0.670096
# 24         480  ../output/okhttp/matrix-window-size/square-okh...  0.670096
# 25         500  ../output/okhttp/matrix-window-size/square-okh...  0.670490
# 26         520  ../output/okhttp/matrix-window-size/square-okh...  0.670490
# 27         540  ../output/okhttp/matrix-window-size/square-okh...  0.671289
# 28         560  ../output/okhttp/matrix-window-size/square-okh...  0.671289
# 29         580  ../output/okhttp/matrix-window-size/square-okh...  0.671289
# 30         600  ../output/okhttp/matrix-window-size/square-okh...  0.671289

# %%
df['apfd'].idxmax()
# Out:
# 2

# %%
alt.Chart(df).mark_line().encode(
  x=alt.X('windowSize'),
  y=alt.Y('apfd'),
)
# Out:
# /Users/falco/.local/share/virtualenvs/testmining-L_g6SVF2/lib/python3.6/site-packages/altair/utils/core.py:294: FutureWarning: A future version of pandas will default to `skipna=True`. To silence this warning, pass `skipna=True|False` explicitly.
#   attrs['type'] = infer_vegalite_type(data[attrs['field']])
