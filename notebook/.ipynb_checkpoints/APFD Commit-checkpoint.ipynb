# %%
from util import setup_notebook
setup_notebook()
# %load_ext autoreload
# %autoreload 2

# %%
import os
os.environ['PRIO_QUALIFIER'] = 'experimental'

import pandas as pd

from testmining import folders

strategy = 'matrix-file-similarity'

apfd = pd.read_csv(folders.apfd('../output/square@okhttp'))[['travisJobId', strategy]]
apfd.head()
# Out:
#    travisJobId  matrix-file-similarity
# 0      2685384                0.820144
# 1      2697352                0.701510
# 2      2820645                0.825784
# 3      2923196                0.826389
# 4      2923220                0.826389

# %%
import json
cache = '/Users/falco/tmp/matrix/cache'

def collect():
    rows = []
    for job_id in apfd['travisJobId']:
        with open(os.path.join(cache, '%s.json' % job_id)) as fd:
           m = json.load(fd)['matrix']
        files = set()
        for index in range(0, len(m), 2):
            files.add(m[index]['fileName'])
        rows.append((job_id, len(files)))
    return pd.DataFrame(rows, columns=['travisJobId', 'fileCount'])

counts = collect()
counts.head()
# Out:
#    travisJobId  fileCount
# 0      2685384          7
# 1      2697352          4
# 2      2820645          1
# 3      2923196          2
# 4      2923220          2

# %%
df = pd.merge(left=apfd, right=counts, on='travisJobId', validate='1:1')
df.head()
# Out:
#    travisJobId  matrix-file-similarity  fileCount
# 0      2685384                0.820144          7
# 1      2697352                0.701510          4
# 2      2820645                0.825784          1
# 3      2923196                0.826389          2
# 4      2923220                0.826389          2

# %%
import altair as alt

alt.Chart(df).mark_point(filled=True).encode(x='fileCount',
                                             y=strategy,
                                             color=strategy)
# Out:
# <div class="vega-embed" id="138ce98c-0d21-4e4d-b222-aa047782aa8f"></div>
#
# <style>
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 14px;
# }
# </style>

# %%
alt.Chart(df).mark_bar().encode(x=alt.X('fileCount', bin=alt.BinParams(step=3)),
                                y=alt.Y('median(%s)' % strategy, scale=alt.Scale(domain=[0, 1]), axis=alt.Axis(format='%')))
# Out:
# <div class="vega-embed" id="14ec3c31-7a4b-4238-888b-0c024f26da19"></div>
#
# <style>
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 14px;
# }
# </style>
