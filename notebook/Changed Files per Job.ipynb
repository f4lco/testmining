# %%
from util import setup_notebook
setup_notebook()
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pandas as pd
import altair as alt

# %%
df = pd.read_csv('../output/square@okhttp/okhttp-job-commits.csv')
df.head()
# Out:
#    tr_build_id  count
# 0    117166429     16
# 1     23247872      6
# 2      3829395     50
# 3     23439180     30
# 4     62784505     12

# %%
alt.Chart(df).mark_area().encode(
  x=alt.X('count'),
  y=alt.Y('count()'))

# %%
df['count'].idxmax(), df['count'].max()
# Out:
# (384, 2016)

# %%
df[df['count'] > 2000]
# Out:
#       tr_build_id  count
# 384      97158816   2016
# 2696     97153419   2016
# 3429     97153416   2016

# %%
df.describe()
# Out:
#         tr_build_id        count
# count  3.441000e+03  3441.000000
# mean   4.612860e+07    24.508573
# std    3.818907e+07    70.670316
# min    2.685383e+06     2.000000
# 25%    1.940274e+07     4.000000
# 50%    2.736847e+07    10.000000
# 75%    6.234002e+07    24.000000
# max    1.559214e+08  2016.000000

# %%
df['count'].median()
# Out:
# 10.0
