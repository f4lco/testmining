# %%
from util import setup_notebook
setup_notebook()
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd

from testmining import folders
from testmining.fault_distance2 import distance_bar_chart, collect_distances, make_scatter_chart

# %%
strategies = [
    'matrix-recently-changed',
    'recently-failed',
]

# %%
df = collect_distances(strategies)
df.head()
# Out:
#    travisBuildId                 strategy      apfd  distance
# 0        1144786  matrix-recently-changed  0.919355       NaN
# 1        1144786          recently-failed  0.919355       NaN
# 2        1152782  matrix-recently-changed  0.994624       1.0
# 3        1152782          recently-failed  0.994624       1.0
# 4        2567968  matrix-recently-changed  0.995050       1.0

# %%
distance_bar_chart(df)
# Out:
# <div class="vega-embed" id="cfdaf17f-1947-4997-84b6-b8e1c0110a1d"></div>
#
# <style>
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 14px;
# }
# </style>

# %%
make_scatter_chart(df)
# Out:
# <div class="vega-embed" id="c97090c2-fca4-4ef9-9688-6205e29204c3"></div>
#
# <style>
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 14px;
# }
# </style>
