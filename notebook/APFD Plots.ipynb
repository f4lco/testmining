# %%
from util import setup_notebook
setup_notebook()
# %load_ext autoreload
# %autoreload 2

# %%
from testmining import apfd_plot as plots
from testmining import folders

# %%
import pandas as pd

df = pd.read_csv(folders.apfd(folders.project('square@okhttp')))
df.head()
# Out:
#    travisJobId  matrix-path-similarity  matrix-naive  matrix-tc-similarity  \
# 0      2685384                0.820144      0.820144              0.820144
# 1      2697352                0.701510      0.701510              0.701510
# 2      2820645                0.825784      0.825784              0.825784
# 3      2923196                0.826389      0.826389              0.826389
# 4      2923220                0.826389      0.826389              0.826389
#
#    path-tc-overlap     bloom       lru  matrix-conditional-prob  \
# 0         0.359712  0.820144  0.820144                 0.820144
# 1         0.478513  0.701510  0.383275                 0.701510
# 2         0.825784  0.825784  0.181185                 0.825784
# 3         0.437500  0.826389  0.565972                 0.826389
# 4         0.437500  0.826389  0.569444                 0.826389
#
#    optimal-failure  matrix-file-similarity  optimal-failure-duration  \
# ...

# %%
df_bp = plots.boxplot_transform(df)
df_bp.head()
# Out:
#                  strategy      apfd
# 0  matrix-path-similarity  0.820144
# 1  matrix-path-similarity  0.701510
# 2  matrix-path-similarity  0.825784
# 3  matrix-path-similarity  0.826389
# 4  matrix-path-similarity  0.826389

# %%
plots.apfd_boxplot(df_bp, 'square@okhttp')
