# %%
from util import setup_notebook
setup_notebook()
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from testmining.apfd import read_tests

tests = read_tests('../output/neuland@jade4j/baseline/jade4j@recently-failed.csv')

# %%
import pandas as pd
from testmining import pr

df = pd.concat(pr.iterate(tests, [pr.FixedOffset]))
df.head()
# Out:
# 100%|██████████| 26/26 [00:20<00:00,  1.29it/s]
#    precision    recall selector  parameter
# 0        1.0  0.000000    fixed          0
# 0        1.0  0.043478    fixed          1
# 0        1.0  0.090909    fixed          2
# 0        1.0  0.130435    fixed          3
# 0        1.0  0.173913    fixed          4

# %%
pr.chart(df)

# %%
tests = read_tests('../output/deeplearning4j@deeplearning4j/baseline/deeplearning4j@recently-failed.csv')
df = pd.concat(pr.iterate(tests, [pr.FixedOffset]))
pr.chart(df)
# Out:
# 100%|██████████| 11/11 [00:59<00:00,  5.37s/it]
